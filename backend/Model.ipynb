# %% [markdown]
# Model and Tokenizer

# %%
import os
import pickle
import numpy as np
from tqdm.notebook import tqdm
import pandas as pd
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
WORKING_DIR = '/kaggle/working'

# %%
modelf = VGG16()
# restructure the model
modelf = Model(inputs=modelf.inputs, outputs=modelf.layers[-2].output)
# summarize
print(modelf.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
# =================================================================
# Total params: 134260544 (512.16 MB)
# Trainable params: 134260544 (512.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
with open('/kaggle/input/features2/features (4).pkl', 'rb') as f:
    features = pickle.load(f)

# %%
df=pd.read_csv('/kaggle/input/flickr-image-dataset/flickr30k_images/results.csv',delimiter='|')

# %%
df[' comment'] = df[' comment'].astype(str)

# %%
mapping={}
for i in range(len(df)):
    image_id=df["image_name"][i].split('.')[0]
    if image_id not in mapping:
        mapping[image_id] = []

    mapping[image_id].append(df[" comment"][i])

# %%
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            # take one caption at a time
            caption = captions[i]
            # preprocessing steps
            # convert to lowercase
#             caption=caption.astype(str)
            caption = caption.lower()
            # delete digits, special chars, etc., 
            caption = caption.replace('[^A-Za-z]', '')
            # delete additional spaces
            caption = caption.replace('\s+', ' ')
            # add start and end tags to the caption
            caption = 'startseq ' + " ".join([word for word in caption.split() if len(word)>1]) + ' endseq'
            captions[i] = caption

# %%
clean(mapping)

# %%
mapping
# Out:
# {'1000092795': ['startseq two young guys with shaggy hair look at their hands while hanging out in the yard endseq',
#   'startseq two young white males are outside near many bushes endseq',
#   'startseq two men in green shirts are standing in yard endseq',
#   'startseq man in blue shirt standing in garden endseq',
#   'startseq two friends enjoy time spent together endseq'],
#  '10002456': ['startseq several men in hard hats are operating giant pulley system endseq',
#   'startseq workers look down from up above on piece of equipment endseq',
#   'startseq two men working on machine wearing hard hats endseq',
#   'startseq four men on top of tall structure endseq',
#   'startseq three men on large rig endseq'],
#  '1000268201': ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#   'startseq little girl in pink dress going into wooden cabin endseq',
#   'startseq little girl climbing the stairs to her playhouse endseq',
#   'startseq little girl climbing into wooden playhouse endseq',
#   'startseq girl going into wooden building endseq'],
#  '1000344755': ['startseq someone in blue shirt and hat is standing on stair and leaning against window endseq',
#   'startseq man in blue shirt is standing on ladder cleaning window endseq',
#   'startseq man on ladder cleans the window of tall building endseq',
#   'startseq man in blue shirt and jeans on ladder cleaning windows endseq',
#   'startseq man on ladder cleans window endseq'],
#  '1000366164': ['startseq two men one in gray shirt one in black shirt standing near stove endseq',
#   'startseq two guy cooking and joking around with the camera endseq',
#   'startseq two men in kitchen cooking food on stove endseq',
#   'startseq two men are at the stove preparing food endseq',
#   'startseq two men are cooking meal endseq'],
#  '1000523639': ['startseq two people in the photo are playing the guitar and the other is poking at him endseq',
#   'startseq man in green holds guitar while the other man observes his shirt endseq',
#   'startseq man is fixing the guitar players costume endseq',
#   "startseq guy stitching up another man 's coat endseq",
#   'startseq the two boys playing guitar endseq'],
#  '1000919630': ['startseq man sits in chair while holding large stuffed animal of lion endseq',
#   'startseq man is sitting on chair holding large stuffed animal endseq',
#   'startseq man completes the finishing touches on stuffed lion endseq',
#   'startseq man holds large stuffed lion toy endseq',
#   'startseq man is smiling at stuffed lion endseq'],
#  '10010052': ['startseq girl is on rollerskates talking on her cellphone standing in parking lot endseq',
#   'startseq trendy girl talking on her cellphone while gliding slowly down the street endseq',
#   'startseq young adult wearing rollerblades holding cellular phone to her ear endseq',
#   'startseq there is young girl on her cellphone while skating endseq',
#   'startseq woman talking on cellphone and wearing rollerskates endseq'],
#  '1001465944': ['startseq an asian man wearing black suit stands near dark-haired woman and brown-haired woman endseq',
#   'startseq three people are standing outside near large pipes and metal railing endseq',
#   'startseq young woman walks past two young people dressed in hip black outfits endseq',
#   'startseq woman with large purse is walking by gate endseq',
#   'startseq several people standing outside building endseq'],
#  '1001545525': ['startseq two men in germany jumping over rail at the same time without shirts endseq',
#   'startseq two youths are jumping over roadside railing at night endseq',
#   'startseq boys dancing on poles in the middle of the night endseq',
#   'startseq two men with no shirts jumping over rail endseq',
#   'startseq two guys jumping over gate together endseq'],
#  '1001573224': ['startseq five ballet dancers caught mid jump in dancing studio with sunlight coming through window endseq',
#   'startseq ballet dancers in studio practice jumping with wonderful form endseq',
#   'startseq five girls are leaping simultaneously in dance practice room endseq',
#   'startseq five girls dancing and bending feet in ballet class endseq',
#   'startseq ballet class of five girls jumping in sequence endseq'],
#  '1001633352': ['startseq three young men and young woman wearing sneakers are leaping in midair at the top of flight of concrete stairs endseq',
#   'startseq four casually dressed guys jumping down stairway outdoors with stone wall behind them endseq',
#   'startseq four guys three wearing hats one not are jumping at the top of staircase endseq',
#   'startseq four men with excited faces are jumping down from the top of stairs endseq',
#   'startseq four people are jumping from the top of flight of stairs endseq'],
#  '1001773457': ['startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#   'startseq black dog and tri-colored dog playing with each other on the road endseq',
#   'startseq two dogs of different breeds looking at each other on the road endseq',
#   'startseq two dogs on pavement moving toward each other endseq',
#   'startseq black dog and spotted dog are fighting endseq'],
#  '1001896054': ['startseq man with reflective safety clothes and ear protection drives john deere tractor on road endseq',
#   'startseq john deere tractors cruises down street while the driver wears easy to see clothing endseq',
#   'startseq man in neon green and orange uniform is driving on green tractor endseq',
#   'startseq man in tractor wearing headphones driving down paved street endseq',
#   'startseq man driving john deere tractor on main road in the country endseq'],
#  '100197432': ['startseq some women are standing in front of bus with buildings behind it endseq',
#   'startseq several women stand on city street with tall buildings endseq',
#   'startseq group of women are standing in front of bus endseq',
#   'startseq several women wait outside in city endseq',
#   'startseq women are standing outside endseq'],
#  '100207720': ['startseq young woman with dark hair and wearing glasses is putting white powder on cake using sifter endseq',
#   'startseq lady in black top with glasses is sprinkling powdered sugar on bundt cake endseq',
#   'startseq woman wearing glasses sprinkles powdered sugar onto her bundt cake endseq',
#   'startseq girl in black jacket sifting powdered sugar over chocolate cake endseq',
#   'startseq standing woman holds pan over cake endseq'],
#  '1002674143': ['startseq small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it endseq',
#   'startseq little girl covered in paint sits in front of painted rainbow with her hands in bowl endseq',
#   'startseq there is girl with pigtails sitting in front of rainbow painting endseq',
#   'startseq little girl is sitting in front of large painted rainbow endseq',
#   'startseq young girl with pigtails painting outside in the grass endseq'],
#  '1003163366': ['startseq man sleeping on bench outside with white and black dog sitting next to him endseq',
#   'startseq man lays on the bench to which white dog is also tied endseq',
#   'startseq man laying on bench holding leash of dog sitting on ground endseq',
#   'startseq shirtless man lies on park bench with his dog endseq',
#   'startseq man lays on bench while his dog sits by him endseq'],
#  '1003420127': ['startseq group of adults inside home sitting on chairs arranged in circle playing type of musical instruments endseq',
#   'startseq five musicians man and four women practicing sheet music (using flutes in living room endseq',
#   'startseq people gathered in circle some holding musical instruments endseq',
#   'startseq people gathered in room to talk about their favorite tunes endseq',
#   'startseq five people are sitting in circle with instruments endseq'],
#  '1003428081': ['startseq two women both wearing glasses are playing clarinets and an elderly woman is playing stringed instrument endseq',
#   'startseq at least four instrumentalists play clarinets and other instruments in curtained room endseq',
#   'startseq four women in living room three of which are clearly playing musical instrument endseq',
#   'startseq bunch of elderly women play their clarinets together as they read off sheet music endseq',
#   'startseq group of four women are performing music on their instruments endseq'],
#  '100444898': ['startseq person in gray stands alone on structure outdoors in the dark endseq',
#   'startseq large structure has broken and is laying in roadway endseq',
#   'startseq man in gray coat is standing on washed out bridge endseq',
#   'startseq man stands on wooden supports and surveys damage endseq',
#   'startseq man in jacket and jeans standing on bridge endseq'],
#  '1005216151': ['startseq man in white t-shirt looks toward the camera surrounded by crowd near metro station endseq',
#   'startseq large crowd of people stand outside in front of the entrance to metro station endseq',
#   'startseq group of people are walking through city street endseq',
#   'startseq crowd is portrayed near metro station endseq',
#   'startseq crowd standing outside metro area endseq'],
#  '100577935': ["startseq man with goatee in black shirt and white latex gloves is using tattoo gun to place tattoo on someone 's back endseq",
#   "startseq man is putting tattoo on another 's man upper back endseq",
#   'startseq man with black shirt giving another man tattoo endseq',
#   'startseq man is putting tattoo on his back endseq',
#   'startseq man getting tattoo on his back endseq'],
#  '1006452823': ['startseq two children girl and boy are practicing their writing endseq',
#   'startseq two children sit on small seesaw in the sand endseq',
#   'startseq two children sitting on teeter totter endseq',
#   'startseq kids playing on seesaw endseq',
#   'startseq two kids sit on seesaw endseq'],
#  '100652400': ['startseq man in blue hard hat and orange safety vest stands in an intersection while holding flag endseq',
#   'startseq man wearing hard hat and caution vest is standing in the street waving an orange flag endseq',
#   'startseq man in bright vest and hard hat holds flag on street corner covered in spray paint endseq',
#   'startseq construction worker is standing in the street and holding red flag endseq',
#   'startseq man wearing reflective vest and hard hat holds flag in the road endseq'],
#  '1007129816': ['startseq the man with pierced ears is wearing glasses and an orange hat endseq',
#   'startseq man with glasses is wearing beer can crocheted hat endseq',
#   'startseq man with gauges and glasses is wearing blitz hat endseq',
#   'startseq man in an orange hat starring at something endseq',
#   'startseq man wears an orange hat and glasses endseq'],
#  '100716317': ['startseq person with long gray hair has beret with beige and white wearing blue raincoat is painting marketplace scenery surrounded by other artists and paintings endseq',
#   'startseq person dressed in blue coat is standing in on busy sidewalk studying painting of street scene endseq',
#   'startseq person with gray hair is painting in public place surrounded by others who are also painting endseq',
#   'startseq lady in blue coat with white and brown hat standing in front of painting endseq',
#   'startseq passerby admiring painting at an outdoor art fair endseq'],
#  '1007205537': ['startseq man stands on one foot while holding on to waste basket endseq',
#   'startseq man in green pants and blue shirt pushing cart endseq',
#   'startseq janitor pushing dolly outside with janitor tools endseq',
#   'startseq man in green pants walking down the road endseq',
#   'startseq man in bright pants is pushing cart endseq'],
#  '1007320043': ['startseq small child grips onto the red ropes at the playground endseq',
#   'startseq little girl in pink climbs rope bridge at the park endseq',
#   'startseq the small child climbs on red ropes on playground endseq',
#   'startseq little girl climbing on red roping endseq',
#   'startseq child playing on rope net endseq'],
#  '100759042': ['startseq young man in jacket holding toothpick with something on the end of it endseq',
#   'startseq young man traveling on bus with piece of flower in his hands endseq',
#   'startseq teen holding an unknown object for photographers endseq',
#   'startseq young man on train holds an origami crane endseq',
#   'startseq you know am looking like justin bieber endseq'],
#  '10082347': ['startseq young blond man in blue and yellow jacket smiling while standing in front of net endseq',
#   'startseq young man in black and yellow jacket is gazing at something and smiling endseq',
#   'startseq young man holding pole vault looks determined endseq',
#   'startseq man is holding pole and smiling endseq',
#   'startseq smiling man looking at the sky endseq'],
#  '10082348': ['startseq man with baseball cap and black jacket stands in bathroom while holding coffee mug endseq',
#   'startseq man is wearing ball cap and holding coffee cup between to urinals endseq',
#   'startseq man is posing next to urinal with cup of coffee endseq',
#   'startseq man holds coffee cup while in the bathroom endseq',
#   'startseq man standing at urinal with coffee cup endseq'],
#  '100845130': ['startseq five people walking with multicolored sky in the background endseq',
#   'startseq four people walking through the sunset in clear blue skies endseq',
#   'startseq four people walking with the sun setting behind them endseq',
#   "startseq four silhouettes decorate the horizon 's sunset endseq",
#   'startseq group of people walking as the sun sets endseq'],
#  '10090841': ['startseq man with black hair sits in restaurant with glass of beer endseq',
#   'startseq man is sitting at table with drink endseq',
#   'startseq man is sitting at table with beer endseq',
#   'startseq dark-haired man sitting drinking endseq',
#   'startseq old man having beer alone endseq'],
#  '1009434119': ['startseq black and white dog is running in grassy garden surrounded by white fence endseq',
#   'startseq boston terrier is running on lush green grass in front of white fence endseq',
#   'startseq black and white dog is running through the grass endseq',
#   'startseq dog runs on the green grass near wooden fence endseq',
#   'startseq boston terrier is running in the grass endseq'],
#  '1009692167': ['startseq an officer in reflective vest stands at the front of his van with his dog endseq',
#   'startseq trained police dog sits next to his handler in front of the police van endseq',
#   'startseq security man with his watch dog is looking for something endseq',
#   'startseq policeman is standing with german shepherd dog endseq',
#   'startseq policeman stops on street with search dog endseq'],
#  '101001624': ['startseq the white out conditions of snow on the ground seem to almost obliverate the details of man dressed for the cold weather in heavy jacket and red hat riding bicycle in suburban neighborhood endseq',
#   'startseq young boy rides bike down snow covered road endseq',
#   'startseq boy in the snow riding his bike down the street endseq',
#   'startseq person riding bike on snowy road endseq',
#   'startseq person riding bike in snow endseq'],
#  '1010031975': ['startseq five men uniformly dressed in white shirts tie and black slacks converse at the back of an open van endseq',
#   'startseq small group of white males in white suits hanging out by the back of van in parking lot talking endseq',
#   'startseq five men in white short-sleeved shirts and ties stand in parking lot endseq',
#   'startseq group of men wearing ties talk while standing on the street endseq',
#   'startseq colleges stop to take break from there business meetings endseq'],
#  '1010087179': ['startseq tan man with backwards hat looks at the camera while walking through factory endseq',
#   'startseq older man working in factory not looking too excited about the photograph endseq',
#   'startseq man in white shirt and black camp among many machines endseq',
#   'startseq man with backwards hat works on machinery endseq',
#   'startseq man wearing backwards cap at work endseq'],
#  '1010087623': ['startseq caucasian man wearing short-sleeved black shirt and dark-skinned woman wearing sleeveless dress are working at conveyor endseq',
#   'startseq black woman and white man working in factory setting packing jars with candles into boxes endseq',
#   'startseq woman is sorting white tall candles as man in green shirt stands behind her endseq',
#   'startseq warehouse manager assisting an employee endseq',
#   'startseq two people working on an assembly line endseq'],
#  '10101477': ['startseq man wearing blue and white outfit holding broom with traditional asian architecture in the background endseq',
#   'startseq asian man wearing white top and baby blue bottoms is using broom to remove the dirt of the pavement endseq',
#   'startseq man in white and blue kimono is using broom to sweep pavement endseq',
#   'startseq man sweeping the street outside endseq',
#   'startseq asian man sweeping the walkway endseq'],
#  '1010470346': ['startseq two men in florescent vests are standing next to parked cars in front of small building while one of them converses with driver and woman on bike is seen riding by endseq',
#   'startseq man leans into car to talk to the driver as man on bicycle looks on endseq',
#   'startseq man on bicycle watching row of cars waiting to go through checkpoint endseq',
#   'startseq park ranger talking to tourist endseq',
#   'startseq two cars are parked outside endseq'],
#  '1010673430': ['startseq little girl in pink shirt and little girl in an orange shirt sitting in the grass endseq',
#   'startseq two young children eating snack and playing in the grass endseq',
#   'startseq two young toddlers outside on the grass endseq',
#   'startseq two infants are at play in the yard endseq',
#   'startseq female babies eating chips endseq'],
#  '101093029': ['startseq person in tan pants is inside silver mobile object while people watch endseq',
#   'startseq people are watching person in weird vehicle in plaza endseq',
#   'startseq man in blue shirt driving segway type vehicle endseq',
#   'startseq showing of product to advertise endseq',
#   'startseq crowd admiring modern art endseq'],
#  '101093045': ['startseq man in black approaches strange silver object containing person while many onlookers observe from behind roped off barrier endseq',
#   'startseq person drives around futuristic looking vehicle while man approaches her and crowd watches endseq',
#   'startseq person riding in futuristic single-person vehicle endseq',
#   'startseq man walking up to silver 4-wheeled chair endseq',
#   'startseq man walks by silver vehicle endseq'],
#  '1011572216': ['startseq bride and groom walking side by side out of focus on pathway next to brick building endseq',
#   'startseq beautiful bride walking on sidewalk with her new husband endseq',
#   'startseq recently married couple pose for the camera endseq',
#   'startseq groom and bride are standing arm in arm endseq',
#   'startseq couple getting married endseq'],
#  '1012150929': ["startseq little boy plays with nintendo gamecube controller inside mcdonald 's endseq",
#   "startseq young boy plays video game in mcdonald 's restaurant endseq",
#   "startseq young boy plays with gamecube kiosk at mcdonald 's endseq",
#   "startseq little boy playing gamecube at mcdonald 's endseq",
#   "startseq little kid playing gamecube at mcdonald 's endseq"],
#  '1012212859': ['startseq white dog with brown ears standing near water with head turned to one side endseq',
#   'startseq dog with orange ball at feet stands on shore shaking off water endseq',
#   'startseq white dog shakes on the edge of beach with an orange ball endseq',
#   'startseq white dog playing with red ball on the shore near the water endseq',
#   'startseq dog shakes its head near the shore red ball next to it endseq'],
#  '1012328893': ['startseq group of people picnicking at picnic tables in front of playground endseq',
#   'startseq group of people enjoying beautiful day in the park endseq',
#   'startseq group of people are having picnic at the park endseq',
#   'startseq the reunion is in full swing with moon bounce endseq',
#   'startseq group of people having barbecue at park endseq'],
#  '101262930': ['startseq two asian or spanish people woman and man sitting together in front of glass window as cars pass endseq',
#   'startseq man in sunglasses puts his arm around woman in black and white blouse endseq',
#   'startseq man in sunglasses puts his arm around woman endseq',
#   'startseq man and woman pose in front of some traffic endseq',
#   'startseq an asian couple sitting on the bench endseq'],
#  '1013536888': ['startseq women are seated at picnic table eating while man in white t-shirt and yellow and orange balloon design on his head stands in the background endseq',
#   'startseq an elderly woman is eating burger while the man next to her touching his hat endseq',
#   'startseq man with balloon hat and people eating outdoors at picnic tables endseq',
#   'startseq two older women sit at table with two coolers in front of them endseq',
#   'startseq gray-haired person with glasses enjoys sandwich endseq'],
#  '101362133': ['startseq young female student performing downward kick to break board held by her karate instructor endseq',
#   'startseq girl about to kick piece of wood in half while karate instructor holds it endseq',
#   'startseq girl kicking stick that man is holding in tae kwon do class endseq',
#   'startseq girl in karate uniform breaking stick with front kick endseq',
#   'startseq girl breaking boards by using karate endseq'],
#  '101362650': ['startseq two people are demonstrating martial arts to crowd and jumping over three youngsters who are crouched on the mat endseq',
#   'startseq boy jump kicking over three kids kicking wood during tae kwon do competition endseq',
#   'startseq boy jumps over three other students in martial arts demonstration endseq',
#   'startseq crowd is watching group of five martial artists perform endseq',
#   'startseq crowd of people watch martial arts demonstration endseq'],
#  '1014609273': ['startseq people on two balconies and man climbing up pipe towards the lower balcony getting liquid poured on him endseq',
#   'startseq kid in red sweatshirt is reaching to hand something to man in white shirt endseq',
#   'startseq young boy empties bottle over the railing of balcony unto the man below endseq',
#   'startseq boy in red jacket pouring water on man in white shirt endseq',
#   'startseq young man pouring the contents of bottle endseq'],
#  '101471792': ['startseq man with red jacket is shielding himself from the sun trying to read piece of paper endseq',
#   'startseq man wearing red coat is outside with his hand over his head to block out the sun endseq',
#   'startseq man in red jacket shades the sun from his eyes on busy street endseq',
#   'startseq an elderly man in red jacket shielding his face from the sun endseq',
#   'startseq man in red jacket shielding face from the sun to read endseq'],
#  '1014785440': ['startseq two men are carrying children on their backs down the street on sunny day in nice neighborhood endseq',
#   'startseq two men each with small child on their backs walk on paved road endseq',
#   'startseq two men are out for stroll with their two young children endseq',
#   'startseq men walking down street with children endseq',
#   'startseq two men walking with children endseq'],
#  '1015118661': ['startseq smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him endseq',
#   'startseq little boy is standing on the street while man in overalls is working on stone wall endseq',
#   'startseq young child is walking on stone paved street with metal pole and man behind him endseq',
#   'startseq boy smiles in front of stony wall in city endseq',
#   'startseq young boy runs aross the street endseq'],
#  '1015584366': ['startseq mottled black and gray dog in blue collar jumping over fallen tree endseq',
#   'startseq gray dog is leaping over fallen tree endseq',
#   'startseq large black dog leaps fallen log endseq',
#   'startseq the black dog jumped the tree stump endseq',
#   'startseq black dog leaps over log endseq'],
#  '101559400': ['startseq men in the business suits are crossing the street and there are people with placards are gathering on the street endseq',
#   'startseq man in suit runs across an intersection while large group of people assembles endseq',
#   'startseq man in suit is running past two other gentleman also dressed in suit endseq',
#   'startseq man in suit is hurrying across the street endseq',
#   'startseq man in suit is running across the street endseq'],
#  '1015712668': ['startseq man in red long-sleeved shirt bikes over body of water on bridge endseq',
#   'startseq man riding his bike across the bridge that is over the river endseq',
#   'startseq man in red on bicycle rides past glass structure endseq',
#   'startseq man in red shirt riding his bicycle around water endseq',
#   'startseq man in red shirt rides his bicycle endseq'],
#  '10160966': ['startseq barefooted man wearing olive green shorts grilling hotdogs on small propane grill while holding blue plastic cup endseq',
#   'startseq guy in shorts and white t-shirt sits on the ground in front of grill with hotdogs on it endseq',
#   'startseq young man in sunglasses holds blue cup next to grill with sausages endseq',
#   'startseq young man wearing white shirt prepares hotdogs on small grill endseq',
#   'startseq man is holding his cup while he grills hotdogs endseq'],
#  '101654506': ['startseq the white and brown dog is running over the surface of the snow endseq',
#   'startseq white and brown dog is running through snow covered field endseq',
#   'startseq brown and white dog is running through the snow endseq',
#   'startseq dog running through snow endseq',
#   'startseq dog is running in the snow endseq'],
#  '1016626169': ['startseq man on scooter attracts attention from some of those in large crowd endseq',
#   'startseq crowd is standing and waiting for the green light endseq',
#   'startseq people stop and look at an older woman outside endseq',
#   'startseq crowd of people waiting to cross street endseq',
#   'startseq crowd of people waiting for the light endseq'],
#  '101669240': ['startseq person wearing skis looking at framed pictures set up in the snow endseq',
#   'startseq man in hat is displaying pictures next to skier in blue hat endseq',
#   'startseq man skis past another man displaying paintings in the snow endseq',
#   'startseq skier looks at framed pictures in the snow next to trees endseq',
#   'startseq man on skis looking at artwork for sale in the snow endseq'],
#  '1016887272': ['startseq several climbers in row are climbing the rock while the man in red watches and holds the line endseq',
#   'startseq seven climbers are ascending rock face whilst another man stands holding the rope endseq',
#   'startseq group of people are rock climbing on rock climbing wall endseq',
#   'startseq group of people climbing rock while one man belays endseq',
#   'startseq collage of one person climbing cliff endseq'],
#  '1017675163': ['startseq young gymnast jumps high in the air while performing on balance beam endseq',
#   'startseq woman wearing an orange leotard doing gymnastics in front of an audience endseq',
#   'startseq gymnast performing on the balance beam in front of an audience endseq',
#   "startseq the young gymnast 's supple body soars above the balance beam endseq",
#   'startseq gymnast is performing on the balance beam endseq'],
#  '1018057225': ['startseq boy in black t-shirt and blue jeans is pushing toy three wheeler around small pool endseq',
#   'startseq young boy is pushing toy atv around rubber pool endseq',
#   'startseq boy pushing red toy atv next to pool endseq',
#   'startseq boy pushing miniature car on lawn endseq',
#   'startseq young boy pushing his toy quad endseq'],
#  '1018148011': ['startseq group of people stand in the back of truck filled with cotton endseq',
#   'startseq men are standing on and about truck carrying white substance endseq',
#   'startseq group of people are standing on pile of wool in truck endseq',
#   'startseq group of men are loading cotton onto truck endseq',
#   'startseq workers load sheared wool onto truck endseq'],
#  '101859883': ['startseq woman with red jacket and headscarf looks out over scenic view of bay through set of pay binoculars on viewing deck endseq',
#   'startseq woman inside building is wearing headscarf and looking out of window through mounted telescope endseq',
#   'startseq woman in red windbreaker looking though rooftop binoculars at the city below endseq',
#   'startseq woman in headscarf uses telescope to look out over the city and bay endseq',
#   'startseq woman is looking through telescope while wearing red coat endseq'],
#  '10188041': ['startseq man in black coat walks past red spaceship with parking ticket stuck to its window endseq',
#   'startseq man is standing in front of small red object that looks like plane endseq',
#   'startseq man wearing black jacket is walking towards the street endseq',
#   'startseq man in black jacket is moving towards street endseq',
#   'startseq man in black coat examining airplane nose endseq'],
#  '1019077836': ['startseq large brown dog running away from the sprinkler in the grass endseq',
#   'startseq brown dog chases the water from sprinkler on lawn endseq',
#   'startseq brown dog running on lawn near garden hose endseq',
#   'startseq brown dog plays with the hose endseq',
#   'startseq dog is playing with hose endseq'],
#  '101958970': ['startseq man and little girl happily posing in front of their cart in supermarket endseq',
#   "startseq man sitting with his daughter in his daughter 's pink car in grocery store endseq",
#   'startseq man is sitting on pink cart with little girl in the grocery store endseq',
#   'startseq man with his daughter sitting on stroller in supermarket endseq',
#   'startseq the little girl and the man are smiling endseq'],
#  '1019604187': ['startseq dog prepares to catch thrown object in field with nearby cars endseq',
#   'startseq white dog is ready to catch yellow ball flying through the air endseq',
#   'startseq white dog is about to catch yellow ball in its mouth endseq',
#   'startseq white dog is about to catch yellow dog toy endseq',
#   'startseq white dog running after yellow ball endseq'],
#  '102030371': ['startseq man wearing green shirt and dark colored vest is sitting at table with glass of water in front of him endseq',
#   'startseq guy in green shirt with hand covering part of his face in restaurant booth endseq',
#   'startseq man sitting at table at restaurant with glass of water endseq',
#   'startseq man in green sweater and black vest sitting in booth endseq',
#   'startseq boy in green sweater is sitting at table endseq'],
#  '1020651753': ['startseq white dog is trying to catch ball in midair over grassy field endseq',
#   'startseq the white dog is playing in green field with yellow toy endseq',
#   'startseq black and white dog jumping in the air to get toy endseq',
#   'startseq black and white dog jumps up towards yellow toy endseq',
#   'startseq dog leaps to catch ball in field endseq'],
#  '1021293940': ['startseq two men are hiking in forest where snow is partially covering the ground endseq',
#   'startseq two men hiking in the snowy wilderness endseq',
#   'startseq two hikers resting by patch of snow endseq',
#   'startseq two men look up while hiking endseq',
#   'startseq two men hiking in the snow endseq'],
#  '1021332107': ['startseq an elderly man with facial hair and glasses standing in his living room holding hutch cabinet with glass doors endseq',
#   'startseq an older man in gray shirt with white long-sleeve shirt under it holding up small wooden cabinet endseq',
#   'startseq middle-aged man with white beard and glasses holds up small wooden handmade cabinet endseq',
#   'startseq man showing off his new wooden creation endseq',
#   'startseq man with beard carrying cabinet endseq'],
#  '1021439420': ['startseq two guys sitting on the floor with the guy in the green jacket reading piece of paper endseq',
#   'startseq elderly father and his grown son are preparing for camping trip in the wild endseq',
#   'startseq two men sit on the floor with camping equipment endseq',
#   'startseq two men sitting on their living floor endseq',
#   'startseq two guys sorting through some items endseq'],
#  '1021442086': ['startseq bearded man wearing glasses red shirt and hat is reading map while sitting in car endseq',
#   'startseq bearded traveler in red shirt sitting in car and reading map endseq',
#   'startseq man wearing baseball cap is sitting in car looking at map endseq',
#   'startseq man in red t-shirt is sitting in car looking at map endseq',
#   'startseq man trying to decipher map endseq'],
#  '1022454332': ['startseq large lake with lone duck swimming in it with several people around the edge of it endseq',
#   'startseq young boy waves his hand at the duck in the water surrounded by green park endseq',
#   'startseq two people are at the edge of lake facing the water and the city skyline endseq',
#   'startseq child and woman are at waters edge in big city endseq',
#   'startseq little boy at lake watching duck endseq'],
#  '1022454428': ['startseq couple and an infant being held by the male sitting next to pond with nearby stroller endseq',
#   'startseq man and woman care for an infant along the side of body of water endseq',
#   'startseq couple with their newborn baby sitting under tree facing lake endseq',
#   'startseq couple with baby sit outdoors next to their stroller endseq',
#   'startseq couple sit on the grass with baby and stroller endseq'],
#  '102268204': ['startseq three men are standing at night near black car near shelter filled with bicycles endseq',
#   'startseq some men standing in front of building next to parked car endseq',
#   'startseq there are lot of bikes parked under the curved roof tonight endseq',
#   'startseq police questioning the driver of black wagon at nighttime endseq',
#   'startseq men under dome beside black station wagon endseq'],
#  '1022975728': ['startseq black lab with tags frolicks in the water endseq',
#   'startseq this is black dog splashing in the water endseq',
#   'startseq the black dog runs through the water endseq',
#   'startseq black dog running in the surf endseq',
#   'startseq dog splashes in the water endseq'],
#  '102351840': ['startseq man is drilling through the frozen ice of pond endseq',
#   'startseq person in the snow drilling hole in the ice endseq',
#   'startseq person standing on frozen lake endseq',
#   'startseq man drilling hole in the ice endseq',
#   'startseq two men are ice fishing endseq'],
#  '1024138940': ['startseq two different breeds of brown and white dogs play on the beach endseq',
#   'startseq two dogs are making turn on soft sand beach endseq',
#   'startseq two large tan dogs play along sandy beach endseq',
#   'startseq two dogs playing in the sand at the beach endseq',
#   'startseq two dogs playing together on beach endseq'],
#  '102455176': ['startseq an ice climber in blue jacket and black pants is scaling frozen ice wall endseq',
#   'startseq person in blue and red ice climbing with two picks endseq',
#   'startseq man uses ice picks and crampons to scale ice endseq',
#   'startseq an ice climber scaling frozen waterfall endseq',
#   'startseq climber climbing an ice wall endseq'],
#  '1024613706': ['startseq two young men and young lady walk through field near the water endseq',
#   'startseq three people walking through beautiful meadow towards the ocean endseq',
#   'startseq two men and woman are walking through field endseq',
#   'startseq two males and one female walking on path endseq',
#   'startseq three people walking on path in meadow endseq'],
#  '102520526': ['startseq man in black attire shovels snow into the street disregarding all public safety endseq',
#   'startseq man in black jacket gray snow cap shovels snow near street with cars endseq',
#   'startseq man shoveling snow off the roads and sidewalks in city endseq',
#   'startseq person is cleaning snow and ice off of city sidewalk endseq',
#   'startseq man shovels slush of the street endseq'],
#  '102575576': ['startseq couple in their wedding attire stand behind table with wedding cake and flowers endseq',
#   'startseq bride and groom are standing in front of their wedding cake at their reception endseq',
#   'startseq bride and groom smile as they view their wedding cake at the reception endseq',
#   'startseq couple stands behind their wedding cake endseq',
#   'startseq man and woman cutting wedding cake endseq'],
#  '102617084': ['startseq five snowmobile riders all wearing helmets and goggles line up in snowy clearing in forest in front of their snowmobiles they are all wearing black snow pants and from left to right they are wearing black coat white coat red coat blue coat and black coat endseq',
#   'startseq five people wearing winter jackets and helmets stand in the snow with snowmobiles in the background endseq',
#   'startseq five people wearing winter clothing helmets and ski goggles stand outside in the snow endseq',
#   'startseq group of snowmobile riders gather in the snow endseq',
#   'startseq group gathered to go snowmobiling endseq'],
#  '1026685415': ['startseq black dog carries green toy in his mouth as he walks through the grass endseq',
#   'startseq wet black dog is carrying green toy through the grass endseq',
#   'startseq black dog carrying something through the grass endseq',
#   'startseq dog in grass with blue item in his mouth endseq',
#   'startseq black dog has blue toy in its mouth endseq'],
#  '1026792563': ['startseq group of woman and children are standing or sitting in front of rows of vegetables endseq',
#   'startseq group of women are trying to sell their vegetable harvest endseq',
#   'startseq people lay out vegetables on blankets at street market endseq',
#   'startseq villagers selling their crops at the market endseq',
#   'startseq these are some very large onions endseq'],
#  '1027149103': ['startseq band is playing in front of an audience and the singer is wearing an orange shirt and has tattoos on his arm endseq',
#   'startseq in crowded concert man in white is approaching the main singer who is wearing yellow shirt endseq',
#   'startseq man wearing yellow t-shirt is shouting into microphone while an audience is listening endseq',
#   'startseq man in an orange shirt sings for the crowd below sign that says lucky 13 endseq',
#   'startseq punk rocker screaming on stage at concert endseq'],
#  '1027211271': ['startseq young woman with short blond-hair wearing jeans and striped long-sleeved sweater jumping in midair on skateboard with trees in the background endseq',
#   'startseq young man is in midair while skateboarding at skate park with people watching him in the background endseq',
#   'startseq this person is performing trick in skateboarding competition with people watching in the background endseq',
#   'startseq boy jumps on his skateboard while crowd watches endseq',
#   'startseq someone skateboarding at skate park endseq'],
#  '1028205764': ['startseq man and little boy in blue life jackets are rowing yellow canoe endseq',
#   'startseq man and baby are in yellow kayak on water endseq',
#   'startseq man and child kayak through gentle waters endseq',
#   'startseq man and young boy ride in yellow kayak endseq',
#   'startseq man and child in yellow kayak endseq'],
#  '102851549': ['startseq little boy looks at the camera while woman behind him seems to be laughing very hard and the woman on the right has big smile on her face endseq',
#   'startseq three people on porch of which is little boy who is sitting up straight in his chair endseq',
#   'startseq woman in dark dress smiles while woman across from her and child sit in chairs endseq',
#   'startseq two people are sitting on bench and one women is standing by them endseq',
#   'startseq two women boy sitting on porch the ladies laughing hard endseq'],
#  '102860573': ['startseq construction site on street with three men working endseq',
#   'startseq two men wearing hard hats are in construction area endseq',
#   'startseq two men in orange vests work in road construction endseq',
#   'startseq construction workers installing light post endseq',
#   'startseq workers in orange vests work in street endseq'],
#  '10287332': ['startseq two men sitting on the roof of house while another one stands on ladder endseq',
#   'startseq two men on rooftop while another man stands atop ladder watching them endseq',
#   'startseq three men one on ladder work on roof endseq',
#   'startseq people are fixing the roof of house endseq',
#   'startseq three men are working on roof endseq'],
#  '1028982826': ['startseq two men one younger guy with yellow shirt that has luggage and the other and older guy are sitting on bench in front of large building that has billboard for glasses and sunglasses endseq',
#   'startseq man in yellow shirt with tall gray suitcase sitting next to another man in white shirt and gray pants behind them tall billboard for sunglasses and prescription glasses endseq',
#   'startseq two men sitting on bench talking with billboard advertisement for glasses in the background endseq',
#   'startseq two men sitting on bench in front of sign with picture of man and lady endseq',
#   'startseq men are sitting at bench outside the airport in front of billboard endseq'],
#  '1029450589': ['startseq an adult wearing gray shirt with red sleeves sleeping on couch endseq',
#   'startseq woman in black pants napping on the couch endseq',
#   'startseq man sleeping in green room on couch endseq',
#   'startseq the young woman is sleeping in her room endseq',
#   'startseq long-haired man sleeping on couch endseq'],
#  '1029737941': ["startseq boy in brown shirt with headphones on sits on woman 's shoulders in crowd endseq",
#   "startseq kid wearing headphones sits on his mom 's shoulders while in crowd endseq",
#   "startseq boy with headphones on sitting on top of woman 's shoulders endseq",
#   "startseq child with headphones riding on his mother 's shoulders endseq",
#   "startseq boy wearing headphones sits on woman 's shoulders endseq"],
#  '1029802110': ['startseq during gay pride parade in an asian city some people hold up rainbow flags to show support endseq',
#   'startseq group of youths march down the street waving flags showing the color spectrum endseq',
#   'startseq oriental people with rainbow flags walking down city street endseq',
#   'startseq group of people walk down the street waving rainbow flags endseq',
#   'startseq people are outside waving flags endseq'],
#  '102998070': ['startseq young man in blue sweater cleaning fish while three other men watch one man cigarette or match in his month endseq',
#   'startseq three older men stare into the pan of street vendor who is cooking fish endseq',
#   'startseq three old men are watching another man prepare fish endseq',
#   'startseq fish sellers stock is looked upon by two old men endseq',
#   'startseq three men watch as fish is being prepared endseq'],
#  '1030041880': ['startseq woman in green dress with white top and red-hair singing in room with blue roof while band equipment is being prepared endseq',
#   'startseq red-haired woman in white top and green and white skirt is singing into microphone endseq',
#   'startseq woman in white tank top with green flowing skirt on stage singing song endseq',
#   'startseq woman in green skirt and white tank top singing into microphone endseq',
#   'startseq girl in green skirt is singing karaoke endseq'],
#  '103031977': ['startseq four college-aged individuals two males and two females sitting on the concrete steps outside of brick building endseq',
#   'startseq two guys and two girls sitting on the stairs outside of building endseq',
#   'startseq four people sit on the steps of the entrance to building endseq',
#   'startseq two men and two women sitting on steps outdoors endseq',
#   'startseq multiple students sitting on stairs at school endseq'],
#  '1030985833': ['startseq the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway endseq',
#   'startseq brown and black lab are outside and the black lab is catching toy in its mouth endseq',
#   'startseq black dog and brown dog play with red toy on courtyard endseq',
#   'startseq black dog and brown dog are jumping up to catch red toy endseq',
#   'startseq black dog snaps at red and black object as brown dog lunges endseq'],
#  '103106960': ['startseq young male kneeling in front of hockey goal with hockey stick in his right hand endseq',
#   'startseq child in red jacket playing street hockey guarding goal endseq',
#   'startseq hockey goalie boy in red jacket crouches by goal with stick endseq',
#   'startseq boy with stick kneeling in front of goalie net endseq',
#   'startseq young kid playing the goalie in hockey rink endseq'],
#  '103195344': ['startseq the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading endseq',
#   'startseq man in black is sitting next to modern art structure in front of glass building endseq',
#   'startseq man sits and reads newspaper by sculpture outside of an office building endseq',
#   'startseq man sitting in front of metal sculpture in front of building endseq',
#   'startseq man sits near large statue endseq'],
#  '1031973097': ['startseq toddler in blue shirt with red shorts and hat looks out from behind fenced in area of brick patio endseq',
#   'startseq young child wearing blue shirt and red hat grabs onto black bars in front of him endseq',
#   'startseq the little boy looks like he is saying let me out of jail endseq',
#   'startseq toddler boy in red hat holding on to some railings endseq',
#   'startseq little boy wanting to play outside of fence endseq'],
#  '103205630': ['startseq two men standing on an ice looking into something covered with blue tarp endseq',
#   'startseq two men are about to enter an ice fishing tent on snow covered lake endseq',
#   'startseq two people standing outside blue tent structure on snowy surface endseq',
#   'startseq two men setting up blue ice fishing hut on an iced over lake endseq',
#   'startseq tent is being set up on the ice endseq'],
#  '1032122270': ['startseq three dogs are standing in the grass and person is sitting next to them endseq',
#   'startseq three dogs stand in grassy field while person kneels nearby endseq',
#   'startseq three dogs are playing on grassy hill with blue sky endseq',
#   'startseq woman crouches near three dogs in field endseq',
#   'startseq three dogs on grassy hill endseq'],
#  '1032460886': ['startseq there is skyscraper in the distance with man walking in front of the camera endseq',
#   'startseq behind the man in red shirt stands large skyscraper endseq',
#   'startseq man stands in front of very tall building endseq',
#   'startseq man is standing in front of skyscraper endseq',
#   'startseq man stands in front of skyscraper endseq'],
#  '103306033': ['startseq woman wearing brown dress with matching turban is pushing toddler through park in his stroller endseq',
#   'startseq woman dressed in brown african attire pushing toddler in stroller endseq',
#   'startseq woman is walking her baby with stroller at the local park endseq',
#   'startseq the lady is pushing child in stroller endseq',
#   'startseq woman pushes her baby in stroller endseq'],
#  '103328091': ['startseq asian male wearing red shirt is sitting next to grocery stand selling fruits endseq',
#   'startseq man in red shirt is sitting next to fruit that is for sale endseq',
#   'startseq man in red shirt is sitting by fruit for sale endseq',
#   'startseq man in red shirt sits next to fruit stand endseq',
#   'startseq an oriental man selling produce endseq'],
#  '1033767085': ['startseq young child with band-aid on his head sits eating at small white table with little girl eating off yellow plate endseq',
#   "startseq young blond-haired boy and dark-haired girl are eating at kid 's table endseq",
#   'startseq two children are sitting at table eating food endseq',
#   'startseq two children eating at small table endseq',
#   'startseq two children eating food endseq'],
#  '1034276567': ['startseq small boy putting something in his mouth with both hands endseq',
#   'startseq boy bites hard into treat while he sits outside endseq',
#   'startseq the boy eats his food outside at the table endseq',
# ...
#   'startseq two kids on wakeboards attempt to give one another high-five endseq',
#   'startseq two young kids wakeboarding with one hand each in the air endseq',
#   'startseq two children on surfboards wave to each other endseq'],
#  '130500771': ['startseq man in white shirt and black pants looks on as other people are seated at tables beneath green umbrellas endseq',
#   'startseq man is walking by large outdoor planter and about to enter an outdoor seating area for restaurant endseq',
#   'startseq the camera catches some movement as man walks in front of the alpha dental group building endseq',
#   'startseq an outdoor cafe with people sitting while man in white shirt is walking toward them endseq',
#   'startseq man walks by an outdoor eating area that has several green umbrellas endseq'],
#  '130504182': ['startseq two women one wearing jeans and one wearing white skirt are walking in building endseq',
#   'startseq there are many people with black hair heading through some doors and few coming out endseq',
#   'startseq two women wearing business casual clothing walk into crowded office building endseq',
#   'startseq many people are passing through the general area their backs are turned endseq',
#   'startseq woman in jeans and woman in white skirt are walking in building endseq'],
#  '130508055': ['startseq people are going up towards man in white shirt endseq',
#   'startseq group of people walking up the stairs in mall endseq',
#   'startseq several people walk up flight of stairs endseq',
#   'startseq several people walk up staircase endseq',
#   'startseq people going up an escalator endseq'],
#  '13051044': ['startseq puppeteer wearing purple sleeveless shirt showing off puppet that looks like black man with shades playing saxophone endseq',
#   'startseq man dressed in burgundy shirt and black pants maneuvering puppet which is holding musical instrument endseq',
#   'startseq puppeteer entertaining with puppet playing the saxophone on the side of the street endseq',
#   'startseq man wearing red shirt has puppet band on the street endseq',
#   'startseq man manipulates saxophone playing marionette endseq'],
#  '1305564994': ['startseq two motorists are riding along on their vehicle that is oddly designed and colored endseq',
#   "startseq man in street racer armor is examining the tire of another racer 's motorbike endseq",
#   'startseq two people are in small race car driving by green hill endseq',
#   'startseq the two racers drove the white bike down the road endseq',
#   'startseq two people in racing uniforms in street car endseq'],
#  '1306038218': ['startseq two soccer players one from team wearing red and the other wearing white are both going for the soccer ball while people on the bleachers watch endseq',
#   'startseq two boys one in red and one in white uniform fight for control over the ball during soccer match endseq',
#   "startseq people sitting on bleachers are watching men 's soccer game endseq",
#   'startseq two men on different soccer teams are playing for the ball endseq',
#   'startseq two soccer players going after the same ball endseq'],
#  '1306080718': ['startseq worker is sweeping off sidewalk 302 miles from liverpool endseq',
#   'startseq the man in the green vest is sweeping on the sidewalk endseq',
#   'startseq man in yellow jacket sweeps the street in england endseq',
#   'startseq man in yellow vest sweeping sidewalk endseq',
#   'startseq man sweeps the sidewalk along fence endseq'],
#  '1306106329': ['startseq young asian boy is standing between to women while they cook meat on sticks endseq',
#   'startseq an asian family prepares meat on skewers at night market endseq',
#   'startseq two asian women preparing food while young man watches endseq',
#   'startseq several people are setting out food to sell endseq',
#   'startseq asian people preparing food on skewers endseq'],
#  '1306145560': ['startseq black dog with tennis ball in its mouth swims through water endseq',
#   'startseq black dog carries an orange tennis ball in his mouth as he swims endseq',
#   'startseq dog swims holding tennis ball in its mouth endseq',
#   'startseq the dog is swimming with the ball endseq',
#   'startseq black dog swims in the water endseq'],
#  '13061918': ['startseq two men one standing and one on bicycle are talking outside building endseq',
#   'startseq man riding bike is chatting to man wearing blue uniform endseq',
#   'startseq two uniformed men having conversation outside of factory endseq',
#   'startseq two male worker talking outside their building endseq',
#   'startseq man on bicycle is talking to another man endseq'],
#  '1306755031': ['startseq pedestrians walk through an open area between several traditional-style japanese or chinese buildings endseq',
#   'startseq an area in japan which appears to be extremely crowded with many people of whom look like tourists endseq',
#   'startseq many people are walking in plaza with buildings of asian architecture endseq',
#   'startseq people are walking down sidewalk where there is an outdoors market endseq',
#   'startseq crowd of people fills square in front of pagoda endseq'],
#  '1306824952': ['startseq one adult and three children gathered on the floor looking at picture on digital camera endseq',
#   'startseq teacher and three of her students all enjoy small dose of learning through technology endseq',
#   'startseq three children and an adult view an electronic device that the adult is holding endseq',
#   'startseq the group is watch cartoon on small electric device endseq',
#   'startseq four children on the floor looking at camera endseq'],
#  '1307094208': ['startseq person wearing hat and carrying knapsack walks uphill on sand dune under dark cloudy sky and leaves the only visible footprints behind endseq',
#   'startseq man with shoulder bag walking in the desert on sand with footprints behind him and the horizon with many stormy clouds endseq',
#   'startseq man walking in the desert wearing hat khaki shirt and shorts and very dark sky ahead of him endseq',
#   'startseq one man is walking across desert right into an approaching storm endseq',
#   'startseq man wandering in the desert as the clouds roll in endseq'],
#  '1307635496': ['startseq small male child running through the grass with smile on his face endseq',
#   'startseq boy wearing black sandals runs along the grass endseq',
#   'startseq young boy is walking in grassy field endseq',
#   'startseq smiling boy runs through the grass endseq',
#   'startseq child runs through field endseq'],
#  '130784506': ["startseq brown horse is nuzzling smiling woman 's neck as her hair blows in the wind endseq",
#   'startseq brown horse is standing behind girl and is sniffing her hair endseq',
#   'startseq horse standing behind woman with brown hair endseq',
#   "startseq horse licks brown-haired woman 's back endseq",
#   'startseq woman is being licked by brown horse endseq'],
#  '130792536': ["startseq young man and woman dressed in play chef 's hats are eating food at table endseq",
#   'startseq people are learning to cook and enjoying the results of what they have done endseq',
#   'startseq man and woman are in kitchen eating what they have prepared endseq',
#   'startseq young chefs are arranging food in kitchen endseq',
#   'startseq the people are wearing chef hats endseq'],
#  '1308472581': ['startseq girls with blue bucket is playing and splashing in the ocean water endseq',
#   'startseq the girl with the blue bucket splashes beneath the pier endseq',
#   'startseq laughing girl holding bucket splashes in the ocean endseq',
#   'startseq young girl plays under pier with blue bucket endseq',
#   'startseq boy in blue shirt splashing in water under dock endseq'],
#  '1308617539': ['startseq young boy running with boogie board into the water endseq',
#   'startseq boy is jumping from body board into the ocean endseq',
#   'startseq the little boy runs into the ocean endseq',
#   'startseq child running through the water endseq',
#   'startseq boy splashing through the ocean endseq'],
#  '1309153515': ["startseq three people stand in line waiting to buy something to eat at fair booth selling martins famous louisiana sausage 's sic endseq",
#   'startseq workers are serving up customers lined up in front of martins famous louisiana sausages vendor tent endseq',
#   "startseq group of people line up at tent for martin 's famous louisiana sausages endseq",
#   'startseq people are standing in line to buy sausages endseq',
#   'startseq people are standing in line at food stand endseq'],
#  '1309330801': ['startseq one girl is doing handstand on an outdoor trampoline while another girl stands on the trampoline with one hand in the air endseq',
#   'startseq one girl is doing handstand on trampoline while another girl watches endseq',
#   'startseq two girls jumping on trampoline in backyard endseq',
#   'startseq two girls are performing tricks on trampoline endseq',
#   'startseq the children are playing on the trampoline endseq'],
#  '1310093059': ['startseq the attractive young brunette girl in red bikini jumps into pool in the backyard endseq',
#   'startseq young woman in bikini jumping into backyard in-ground pool endseq',
#   'startseq young woman wearing bikini jumping into pool endseq',
#   'startseq girl in red bikini is jumping into pool endseq',
#   'startseq girl jumps for joy right into the pool endseq'],
#  '131090759': ['startseq man selling many wicker chairs is pulling cart of them through the street endseq',
#   'startseq man pulling cart filled with many wooden chairs down city street endseq',
#   'startseq man pulls wagon full of chairs behind him down city street endseq',
#   'startseq man is pulling cart covered in chairs endseq',
#   'startseq this image with chairs is very blurry endseq'],
#  '1311132744': ['startseq black dog with red collar walks through the grass with his mouth open and tongue hanging out endseq',
#   'startseq dog with red collar and its tongue hanging out runs through tall grass endseq',
#   'startseq black and gray dog runs in field with its tongue hanging out endseq',
#   'startseq black dog with red collar runs through grass endseq',
#   'startseq dog with red collar is running in the field endseq'],
#  '131114016': ['startseq some children are playing on trampoline boy in red shirt is covering his face as he cries endseq',
#   'startseq young boy covering his face while sitting on trampoline endseq',
#   'startseq here is picture of young boy crying inside playhouse endseq',
#   'startseq young kid with red shirt covering his face on trampoline endseq',
#   'startseq boy covers his face while sitting on trampoline endseq'],
#  '131122346': ['startseq four men and women in blue aprons strand in front of table where there are many white plates and small blue bowls endseq',
#   'startseq smiling woman in purple shirt and white apron wiping her hands on napkin endseq',
#   'startseq smiling woman and several other people wear blue aprons and prepare food endseq',
#   'startseq row of people wearing aprons making food endseq',
#   'startseq group of people in aprons prepare food endseq'],
#  '1311388430': ['startseq person hanging from telephone pole near the mountains endseq',
#   'startseq person is hanging in the air from the power lines endseq',
#   'startseq person is hanging upside down from power lines endseq',
#   'startseq someone is suspended from electrical wires endseq',
#   'startseq person hanging upside down from poles endseq'],
#  '131156353': ['startseq man wearing gray shirt blue jeans glasses and sneakers is teeing of golf ball with golf clove endseq',
#   'startseq man wearing gray t-shirt and blue jeans stands ready to hit golf ball at driving range endseq',
#   'startseq man in jeans practicing his golf swing at driving range endseq',
#   'startseq young man practices his golf stance at the driving range endseq',
#   'startseq golf practice by single man on sunny day endseq'],
#  '1312020846': ['startseq two small puppies run along the edge of stone wall nearby heavily foliaged area endseq',
#   'startseq two little puppies chase each other on stone wall endseq',
#   'startseq two puppies run across flat stones in garden area endseq',
#   'startseq two small tan puppies walking on stone path endseq',
#   'startseq two puppies walking on stones endseq'],
#  '1312227131': ['startseq group of dogs is pulling sled over snow as the sun sets endseq',
#   'startseq sled dogs trekking through snow near forest endseq',
#   'startseq dogs are pulling sled across the snow endseq',
#   'startseq dogs running on cold but sunny morning endseq',
#   'startseq two dogs walk through the snow endseq'],
#  '1312269513': ['startseq woman in colorful dress drives motorized chair past corner on city sidewalk while man in long white t-shirt walks towards the road endseq',
#   'startseq lady is in wheelchair on the corner of street and man in white shirt is about to cross the street endseq',
#   'startseq older lady in motorized wheelchair on corner with man walking in front of her endseq',
#   'startseq an older black woman is operating her electric wheelchair endseq',
#   'startseq elderly black woman riding on motorized chair endseq'],
#  '1312440023': ['startseq young men and women sit at wooden table on which several partially-drunk beverages have been placed the picture is interrupted by an outstretched hand colored green in the odd light of the wood-paneled interior endseq',
#   'startseq green tinted hand is being held up in front of table of people endseq',
#   'startseq two guys gather around table with two girls while drinking endseq',
#   'startseq people socializing at table with beverages endseq',
#   'startseq group of friends hanging out in bar endseq'],
#  '131254736': ['startseq two men near railroad tracks with caboose coming by endseq',
#   'startseq two men are standing beside the train tracks endseq',
#   'startseq railroad worker is checking the tracks endseq',
#   'startseq two men in orange work on train tracks endseq',
#   'startseq two men are working on train tracks endseq'],
#  '1312954382': ['startseq little girl on the street in yellowish green and orange dress is holding hello kitty balloon with her right hand endseq',
#   'startseq little girl in an elaborate green and orange dress is chasing after pink and white balloon figure endseq',
#   'startseq girl wearing green and orange dress walks on the street with balloon endseq',
#   'startseq the girl is wearing green dress and holding hello kitty balloon endseq',
#   'startseq girl in green dress plays with hello kitty balloon endseq'],
#  '1313693129': ['startseq two people boy in yellow and girl in brown standing at the shore of lake endseq',
#   'startseq boy and slightly older girl stand on the shore of small blue lake endseq',
#   'startseq boy and girl are standing on riverbank facing the water endseq',
#   'startseq young woman and young boy stand on the shore of river endseq',
#   "startseq two people stand by the water 's edge endseq"],
#  '1313869424': ['startseq shirtless man is fishing standing on large rocks that rest next to boardwalk with tall lamp post in the forefront endseq',
#   'startseq shirtless man in shorts is fishing while standing on some rocks endseq',
#   'startseq shirtless man in jean shorts fishing off the rocks endseq',
#   'startseq solitary fisherman stands along riverbank endseq',
#   'startseq man with no shirt fishing endseq'],
#  '1313961775': ['startseq young girl floats on her back in water and peers over her life jacket endseq',
#   'startseq young girl wearing bulky red life jacket floating in lake endseq',
#   'startseq the little girl is wearing floating device in the water endseq',
#   'startseq girl wearing life vest floats in water endseq',
#   'startseq girl floating wearing life vest endseq'],
#  '1313987366': ['startseq woman in dress is holding camera next to another woman who is laughing endseq',
#   'startseq two young woman are standing in living room laughing and smiling endseq',
#   'startseq these two women are having fun while taking pictures endseq',
#   'startseq two women laughing at cat walking on the furniture endseq',
#   'startseq two young women clap their hands in laughter endseq'],
#  ...}

# %%
all_captions = []
for key in mapping:
    for caption in mapping[key]:
        all_captions.append(caption)

# %%
len(all_captions)
# Out:
# 158915

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1

# %%
max_length = max(len(caption.split()) for caption in all_captions)
max_length
# Out:
# 74

# %%
image_ids = list(mapping.keys())
split = int(len(image_ids) * 0.90)
train = image_ids[:split]
test = image_ids[split:]

# %%
# create data generator to get data in batch (avoids session crash)
def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    # loop over images
    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            captions = mapping[key]
            # process each caption
            for caption in captions:
                # encode the sequence
                seq = tokenizer.texts_to_sequences([caption])[0]
                # split the sequence into X, y pairs
                for i in range(1, len(seq)):
                    # split into input and output pairs
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                    # encode output sequence
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    
                    # store the sequences
                    X1.append(features[key][0])
                    X2.append(in_seq)
                    y.append(out_seq)
            if n == batch_size:
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield {"image": X1, "text": X2}, y
                X1, X2, y = list(), list(), list()
                n = 0

# %%
# encoder model
# image feature layers
inputs1 = Input(shape=(4096,), name="image")
fe1 = Dropout(0.4)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)
# sequence feature layers
inputs2 = Input(shape=(max_length,), name="text")
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.4)(se1)
se3 = LSTM(256)(se2)

# decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

model = Model(inputs=[inputs1, inputs2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# plot the model
plot_model(model, show_shapes=True)

# %%
epochs = 4
batch_size = 32
steps = len(train) // batch_size

for i in range(epochs):
    # create data generator
    generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
    # fit for one epoch
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# 893/893 [==============================] - 327s 361ms/step - loss: 4.6766
# 893/893 [==============================] - 300s 336ms/step - loss: 3.8093
# 893/893 [==============================] - 302s 338ms/step - loss: 3.5465
# 893/893 [==============================] - 300s 336ms/step - loss: 3.3796

# %%
model.save('best_model7.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pickle

# Assuming 'tokenizer' is your tokenizer object
with open('tokenizer7.pkl', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
